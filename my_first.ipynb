# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/Pratik-Bhujade/Diamond-Dataset/master/DiamondData.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#        carat        cut color clarity  depth  table    price     x     y     z
# 0       1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1       0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2       1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3       0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4       2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# ...      ...        ...   ...     ...    ...    ...      ...   ...   ...   ...
# 49995   2.01    Premium     I     SI1   62.4   61.0  15707.0  8.01  7.99  4.99
# 49996   0.80    Premium     G      IF   62.6   58.0   4193.0  5.93  5.89  3.70
# 49997   0.90  Very Good     F     SI2   61.4   62.0   3770.0  6.11  6.20  3.78
# 49998   1.24      Ideal     F     SI2   61.4   58.0   6503.0  6.85  6.90  4.22
# 49999   0.70      Ideal     I    VVS1   61.4   55.0   2489.0  5.70  5.76  3.52
#
# ...

# %%
plt.grid(True)
sns.countplot('cut',data=df);
plt.grid(True)
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price      float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
plt.figure(figsize=(12,6))

sns.scatterplot('cut','price',data=df);
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot('carat','price',data=df)
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
df = df[df['carat']<10]

# %%
df
# Out:
#        carat        cut color clarity  depth  table    price     x     y     z
# 0       1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1       0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2       1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3       0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4       2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# ...      ...        ...   ...     ...    ...    ...      ...   ...   ...   ...
# 49995   2.01    Premium     I     SI1   62.4   61.0  15707.0  8.01  7.99  4.99
# 49996   0.80    Premium     G      IF   62.6   58.0   4193.0  5.93  5.89  3.70
# 49997   0.90  Very Good     F     SI2   61.4   62.0   3770.0  6.11  6.20  3.78
# 49998   1.24      Ideal     F     SI2   61.4   58.0   6503.0  6.85  6.90  4.22
# 49999   0.70      Ideal     I    VVS1   61.4   55.0   2489.0  5.70  5.76  3.52
#
# ...

# %%
plt.figure(figsize=(12,6))
sns.scatterplot('carat','price',data=df,hue='cut')
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
df['cut']=='Very Geod'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Name: cut, Length: 49846, dtype: bool

# %%
df.loc[df['cut']=='Very Geod']
# Out:
#        carat        cut color clarity  depth  table    price     x     y     z
# 17      1.80  Very Geod     J     SI1   61.4   55.0  10107.0  7.86  7.80  4.81
# 29      1.24  Very Geod     G     VS1   62.0   55.0   8298.0  6.89  6.95  4.29
# 31      0.30  Very Geod     J     VS1   62.4   58.0    394.0  4.26  4.30  2.67
# 137     0.31  Very Geod     D     VS1   63.7   58.0    709.0  4.27  4.30  2.73
# 153     0.33  Very Geod     F     SI1   61.2   58.1    544.0  4.48  4.51  2.75
# ...      ...        ...   ...     ...    ...    ...      ...   ...   ...   ...
# 49929   0.24  Very Geod     E    VVS2   63.6   54.0    485.0  3.96  4.00  2.53
# 49934   1.06  Very Geod     F     VS2   61.5   58.0   7706.0  6.53  6.57  4.03
# 49949   0.36  Very Geod     E    VVS1   61.4   56.0   1140.0  4.60  4.62  2.83
# 49972   0.30  Very Geod     H    VVS2   60.8   58.0    605.0  4.34  4.37  2.65
# 49994   0.50  Very Geod     I     SI1   62.4   58.0   1048.0  5.00  5.06  3.14
#
# ...

# %%
df['cut'].value_counts()
# Out:
# Ideal        19851
# Premium      12788
# Very Good     8954
# Good          4544
# Very Geod     2238
# Fair          1471
# Name: cut, dtype: int64

# %%
df.loc[df['cut']=='Very Geod','cut'] = 'Very Good'

# %%
df['cut'].value_counts()
# Out:
# Ideal        19851
# Premium      12788
# Very Good    11192
# Good          4544
# Fair          1471
# Name: cut, dtype: int64

# %%
8954+2238
# Out:
# 11192

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price      float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
plt.figure(figsize=(16,12))
df = df[df['carat']<15]
sns.scatterplot('carat','price',data=df, hue='cut')
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
df['clarity']
# Out:
# 0         SI1
# 1         VS2
# 2         VS1
# 3         VS2
# 4         SI2
#          ...
# 49995     SI1
# 49996      IF
# 49997     SI2
# 49998     SI2
# 49999    VVS1
# Name: clarity, Length: 49846, dtype: object

# %%
df.isnull().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      471
# table      388
# price      252
# x          221
# y          333
# z          425
# dtype: int64

# %%
plt.figure(figsize=(16,10))
sns.distplot(df['price'],kde=False,bins=150)
plt.xlim(0,)
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (0.0, 19747.85)

# %%
df['cut'].value_counts()
# Out:
# Ideal        19851
# Premium      12788
# Very Good    11192
# Good          4544
# Fair          1471
# Name: cut, dtype: int64

# %%
plt.figure(figsize=(12,8))
cut1 = ['Fair','Good','Ideal','Very Good','Premium']
sns.boxplot('cut','price',data=df,palette='GnBu',order=cut1)
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
df.groupby('cut').mean()['price'].sort_values()
# Out:
# cut
# Ideal        3456.449780
# Good         3948.396990
# Very Good    3985.822831
# Fair         4362.375341
# Premium      4590.224743
# Name: price, dtype: float64

# %%
df.groupby('color').count()
# Out:
#        carat    cut  clarity  depth  table  price      x      y      z
# color
# D       6251   6251     6251   6181   6208   6213   6228   6201   6202
# E       9037   9037     9037   8967   8969   8993   9007   8973   8959
# F       8800   8800     8800   8712   8735   8750   8751   8744   8717
# G      10466  10466    10466  10360  10377  10414  10417  10405  10382
# H       7683   7683     7683   7612   7615   7644   7650   7634   7619
# I       5009   5009     5009   4970   4973   4990   4984   4980   4969
# J       2600   2600     2600   2573   2581   2590   2588   2576   2573

# %%
sns.countplot('color',data=df)
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.boxplot('color','price',data=df)
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
df
# Out:
#        carat        cut color clarity  depth  table    price     x     y     z
# 0       1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1       0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2       1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3       0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4       2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# ...      ...        ...   ...     ...    ...    ...      ...   ...   ...   ...
# 49995   2.01    Premium     I     SI1   62.4   61.0  15707.0  8.01  7.99  4.99
# 49996   0.80    Premium     G      IF   62.6   58.0   4193.0  5.93  5.89  3.70
# 49997   0.90  Very Good     F     SI2   61.4   62.0   3770.0  6.11  6.20  3.78
# 49998   1.24      Ideal     F     SI2   61.4   58.0   6503.0  6.85  6.90  4.22
# 49999   0.70      Ideal     I    VVS1   61.4   55.0   2489.0  5.70  5.76  3.52
#
# ...

# %%
df.isnull().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      471
# table      388
# price      252
# x          221
# y          333
# z          425
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#        carat        cut color clarity  depth  table    price     x     y     z
# 0       1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1       0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2       1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3       0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4       2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# ...      ...        ...   ...     ...    ...    ...      ...   ...   ...   ...
# 49995   2.01    Premium     I     SI1   62.4   61.0  15707.0  8.01  7.99  4.99
# 49996   0.80    Premium     G      IF   62.6   58.0   4193.0  5.93  5.89  3.70
# 49997   0.90  Very Good     F     SI2   61.4   62.0   3770.0  6.11  6.20  3.78
# 49998   1.24      Ideal     F     SI2   61.4   58.0   6503.0  6.85  6.90  4.22
# 49999   0.70      Ideal     I    VVS1   61.4   55.0   2489.0  5.70  5.76  3.52
#
# ...

# %%
df.fillna(method='backfill')
# Out:
#        carat        cut color clarity  depth  table    price     x     y     z
# 0       1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1       0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2       1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3       0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4       2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91
# ...      ...        ...   ...     ...    ...    ...      ...   ...   ...   ...
# 49995   2.01    Premium     I     SI1   62.4   61.0  15707.0  8.01  7.99  4.99
# 49996   0.80    Premium     G      IF   62.6   58.0   4193.0  5.93  5.89  3.70
# 49997   0.90  Very Good     F     SI2   61.4   62.0   3770.0  6.11  6.20  3.78
# 49998   1.24      Ideal     F     SI2   61.4   58.0   6503.0  6.85  6.90  4.22
# 49999   0.70      Ideal     I    VVS1   61.4   55.0   2489.0  5.70  5.76  3.52
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['price','cut'],axis=1).values
y = df.price.values

# %%
X
# Out:
# array([[1.5, 'G', 'SI1', ..., 7.15, 7.09, 4.59],
#        [0.7, 'E', 'VS2', ..., 5.72, 5.78, 3.53],
#        [1.22, 'G', 'VS1', ..., 6.91, 6.89, 4.23],
#        ...,
#        [0.9, 'F', 'SI2', ..., 6.11, 6.2, 3.78],
#        [1.24, 'F', 'SI2', ..., 6.85, 6.9, 4.22],
#        [0.7, 'I', 'VVS1', ..., 5.7, 5.76, 3.52]], dtype=object)

# %%
y
# Out:
# array([10352.,  2274.,  8779., ...,  3770.,  6503.,  2489.])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=34)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
df['cut'] = enc.fit_transform(df['cut'])
df['color'] = enc.fit_transform(df['color'])
df['clarity'] = enc.fit_transform(df['clarity'])

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table    price     x     y     z
# 0       1.50    0      3        2   64.5   57.0  10352.0  7.15  7.09  4.59
# 1       0.70    2      1        5   61.4   57.0   2274.0  5.72  5.78  3.53
# 2       1.22    3      3        4   61.3   58.0   8779.0  6.91  6.89  4.23
# 3       0.51    3      1        5   62.5   60.0   1590.0  5.08  5.10  3.18
# 4       2.02    4      6        3   59.2   60.0  11757.0  8.27  8.39  4.91
# ...      ...  ...    ...      ...    ...    ...      ...   ...   ...   ...
# 49995   2.01    3      5        2   62.4   61.0  15707.0  8.01  7.99  4.99
# 49996   0.80    3      3        1   62.6   58.0   4193.0  5.93  5.89  3.70
# 49997   0.90    4      2        3   61.4   62.0   3770.0  6.11  6.20  3.78
# 49998   1.24    2      2        3   61.4   58.0   6503.0  6.85  6.90  4.22
# 49999   0.70    2      5        6   61.4   55.0   2489.0  5.70  5.76  3.52
#
# [49846 rows x 10 columns]

# %%
df.dtypes
# Out:
# carat      float64
# cut          int64
# color        int32
# clarity      int32
# depth      float64
# table      float64
# price      float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
X = df.drop(['price','cut'],axis=1).values
y = df.price.values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=34)

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[0.34120735, 0.16666667, 0.57142857, ..., 0.71104536, 0.22893082,
#         0.71003135],
#        [0.06036745, 0.83333333, 0.14285714, ..., 0.47633136, 0.15251572,
#         0.47021944],
#        [0.30708661, 0.66666667, 0.71428571, ..., 0.70216963, 0.22169811,
#         0.69435737],
#        ...,
#        [0.15748031, 0.5       , 0.14285714, ..., 0.58086785, 0.18647799,
#         0.5799373 ],
#        [0.26246719, 0.5       , 1.        , ..., 0.66469428, 0.21320755,
#         0.65830721],
#        [0.1496063 , 0.33333333, 0.28571429, ..., 0.58678501, 0.18773585,
#         0.55642633]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = df.dropna()

X = df.drop(['price','cut'],axis=1).values
y = df.price.values

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=34)

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Out:
# 1.0

# %%
model = Sequential()

model.add(Dense(9,activation='relu'))
model.add(Dense(9,activation='relu'))
model.add(Dense(9,activation='relu'))
model.add(Dense(9,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='Adam',loss='mse')

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
model.fit(X_train,y_train,epochs=150,validation_split=0.2)
# Out:
# Epoch 1/150
# 837/837 [==============================] - 1s 1ms/step - loss: 24279922.0000 - val_loss: 12906161.0000
# Epoch 2/150
# 837/837 [==============================] - 1s 999us/step - loss: 11486418.0000 - val_loss: 9524967.0000
# Epoch 3/150
# 837/837 [==============================] - 1s 975us/step - loss: 6343469.5000 - val_loss: 3600323.7500
# Epoch 4/150
# 837/837 [==============================] - 1s 934us/step - loss: 2507509.0000 - val_loss: 1905089.7500
# Epoch 5/150
# 837/837 [==============================] - 1s 952us/step - loss: 1620392.5000 - val_loss: 1606616.5000
# Epoch 6/150
# 837/837 [==============================] - 1s 942us/step - loss: 1430942.5000 - val_loss: 1482941.0000
# Epoch 7/150
# 837/837 [==============================] - 1s 945us/step - loss: 1392866.5000 - val_loss: 1464663.1250
# Epoch 8/150
# 837/837 [==============================] - 1s 953us/step - loss: 1370956.0000 - val_loss: 1449958.0000
# Epoch 9/150
# ...

# %%
loss = pd.DataFrame(model.history.history)
loss
# Out:
#              loss      val_loss
# 0    2.427992e+07  1.290616e+07
# 1    1.148642e+07  9.524967e+06
# 2    6.343470e+06  3.600324e+06
# 3    2.507509e+06  1.905090e+06
# 4    1.620392e+06  1.606616e+06
# ..            ...           ...
# 145  1.096349e+06  1.194523e+06
# 146  1.095829e+06  1.196756e+06
# 147  1.096538e+06  1.187401e+06
# 148  1.093176e+06  1.187097e+06
# 149  1.094057e+06  1.227458e+06
#
# [150 rows x 2 columns]

# %%
loss.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_error

# %%
y_pred = model.predict(X_test)

# %%
y_test.shape
# Out:
# (14338,)

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 586.4442290493527

# %%
df.describe()['price']
# Out:
# count    47792.000000
# mean      3938.237697
# std       3994.835546
# min        326.000000
# 25%        948.000000
# 50%       2401.000000
# 75%       5342.000000
# max      18823.000000
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

plt.figure(figsize=(12,8))

plt.scatter(y_test,y_pred,color='orange',alpha=0.5)

plt.xlabel('y_true',fontsize=15, fontweight='bold')
plt.ylabel('y_pred',fontsize=15, fontweight='bold')
plt.plot(y_test,y_test, color='red')
plt.xlim(0,)
plt.ylim(0,)
plt.show()

# %%
new = df.iloc[3].values.reshape(-1,)

# %%
new.shape
# Out:
# (10,)

# %%
model.predict(new)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 8) for input KerasTensor(type_spec=TensorSpec(shape=(None, 8), dtype=tf.float32, name='dense_12_input'), name='dense_12_input', description="created by layer 'dense_12_input'"), but it was called on an input with incompatible shape (None,).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [178], in <cell line: 1>()
# ----> 1 model.predict(new)
#
# File ~\anaconda3\envs\MyTFenv\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# ...
