# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import glob

path = r'C:\Users\Chairman\Downloads\TF_2_Notebooks_and_Data\PRSA2017_Data_20130301-20170228\PRSA_Data_20130301-20170228'

all_files = glob.glob(path+'/*.csv')
df = pd.concat(map(pd.read_csv, all_files),ignore_index=True)

df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
df['No'] = range(1,420769)

# %%
df.set_index('No')
# Out:
#         year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# No
# 1       2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 2       2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 3       2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 4       2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 5       2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# ...      ...    ...  ...   ...    ...   ...   ...   ...    ...   ...   ...
# 420764  2017      2   28    19   11.0  32.0   3.0  24.0  400.0  72.0  12.5
# 420765  2017      2   28    20   13.0  32.0   3.0  41.0  500.0  50.0  11.6
# 420766  2017      2   28    21   14.0  28.0   4.0  38.0  500.0  54.0  10.8
# 420767  2017      2   28    22   12.0  23.0   4.0  30.0  400.0  59.0  10.5
# 420768  2017      2   28    23   13.0  19.0   4.0  38.0  600.0  49.0   8.6
#
#           PRES  DEWP  RAIN   wd  WSPM        station
# No
# ...

# %%
df.dtypes
# Out:
# No           int64
# year         int64
# month        int64
# day          int64
# hour         int64
# PM2.5      float64
# PM10       float64
# SO2        float64
# NO2        float64
# CO         float64
# O3         float64
# TEMP       float64
# PRES       float64
# DEWP       float64
# RAIN       float64
# wd          object
# WSPM       float64
# station     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
df[df.isnull()]
# Out:
#         No  year  month  day  hour  PM2.5  PM10  SO2  NO2  CO  O3  TEMP  PRES  \
# 0      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 1      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 2      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 3      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 4      NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# ...     ..   ...    ...  ...   ...    ...   ...  ...  ...  ..  ..   ...   ...
# 420763 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 420764 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 420765 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 420766 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
# 420767 NaN   NaN    NaN  NaN   NaN    NaN   NaN  NaN  NaN NaN NaN   NaN   NaN
#
# ...

# %%
df['CO'].fillna(method='bfill',inplace=True)
df['NO2'].fillna(method='bfill',inplace=True)

# %%
df['O'] = df['O3'].interpolate(method='linear',limit_direction='forward')

# %%
df['O3'] = df['O']

# %%
df.groupby('station')['NO2'].describe()
# Out:
#                  count       mean        std     min      25%       50%  \
# station
# Aotizhongxin   35064.0  58.857385  37.233372  2.0000  30.0000  53.00000
# Changping      35064.0  44.172286  29.523644  1.8477  22.0000  36.00000
# Dingling       35064.0  27.286832  26.343757  1.0265   8.0000  19.00000
# Dongsi         35064.0  55.711862  36.429338  2.0000  28.0000  48.00000
# Guanyuan       35064.0  58.318545  35.538990  2.0000  31.0000  51.00000
# Gucheng        35064.0  55.850474  36.607169  2.0000  26.0000  50.00000
# Huairou        35064.0  32.111276  26.286924  1.0265  12.0000  25.00000
# Nongzhanguan   35064.0  58.054682  36.377777  2.0000  29.0000  51.00000
# Shunyi         35064.0  43.630191  30.837742  2.0000  20.0000  36.00000
# Tiantan        35064.0  53.280049  32.133187  2.0000  28.0000  47.00000
# Wanliu         35064.0  65.366282  37.831337  1.6424  36.7487  60.98705
# Wanshouxigong  35064.0  55.347417  35.761387  2.0000  28.0000  48.00000
#
# ...

# %%
df.groupby('station').mean()['SO2']
# Out:
# station
# Aotizhongxin     17.375901
# Changping        14.958906
# Dingling         11.749650
# Dongsi           18.531107
# Guanyuan         17.590941
# Gucheng          15.366162
# Huairou          12.121553
# Nongzhanguan     18.689242
# Shunyi           13.572039
# Tiantan          14.367615
# Wanliu           18.376481
# Wanshouxigong    17.148603
# Name: SO2, dtype: float64

# %%
df['SO2_mean'] = df.groupby('station')['SO2'].transform('mean')

# %%
df.head(50)
# Out:
#     No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  TEMP  \
# 0    1  2013      3    1     0    4.0    4.0   4.0    7.0   300.0  77.0  -0.7
# 1    2  2013      3    1     1    8.0    8.0   4.0    7.0   300.0  77.0  -1.1
# 2    3  2013      3    1     2    7.0    7.0   5.0   10.0   300.0  73.0  -1.1
# 3    4  2013      3    1     3    6.0    6.0  11.0   11.0   300.0  72.0  -1.4
# 4    5  2013      3    1     4    3.0    3.0  12.0   12.0   300.0  72.0  -2.0
# 5    6  2013      3    1     5    5.0    5.0  18.0   18.0   400.0  66.0  -2.2
# 6    7  2013      3    1     6    3.0    3.0  18.0   32.0   500.0  50.0  -2.6
# 7    8  2013      3    1     7    3.0    6.0  19.0   41.0   500.0  43.0  -1.6
# 8    9  2013      3    1     8    3.0    6.0  16.0   43.0   500.0  45.0   0.1
# 9   10  2013      3    1     9    3.0    8.0  12.0   28.0   400.0  59.0   1.2
# 10  11  2013      3    1    10    3.0    6.0   9.0   12.0   400.0  72.0   1.9
# ...

# %%
df.SO2_mean.nunique()
# Out:
# 12

# %%
df['SO2'].fillna(df['SO2_mean'],inplace=True)

# %%
df['SO2'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5          0
# PM10           0
# SO2            0
# NO2            0
# CO             0
# O3             0
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# O              0
# SO2_mean       0
# dtype: int64

# %%
df[['PM2.5','PM10']].describe()
# Out:
#                PM2.5           PM10
# count  420768.000000  420768.000000
# mean       79.780235     104.578547
# std        79.984694      91.075152
# min         2.000000       2.000000
# 25%        21.000000      36.000000
# 50%        57.000000      83.739723
# 75%       109.000000     144.000000
# max       999.000000     999.000000

# %%
df['PM2.5'].fillna(df.groupby('station')['PM2.5'].transform('mean'),inplace=True)

# %%
df['PM10'].fillna(df.groupby('station')['PM10'].transform('mean'),inplace=True)

# %%
df.dropna(inplace=True)

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation='vertical',fontsize='14')
sns.countplot('station',data=df);
# Out:
# C:\Users\Chairman\anaconda3\envs\MyTFenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.set_index('No',inplace=True)

# %%
df['No'] = range(1,len(df)+1)

# %%
df.set_index('No')
# Out:
#         year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# No
# 1       2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 2       2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 3       2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 4       2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 5       2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# ...      ...    ...  ...   ...    ...   ...   ...   ...    ...   ...   ...
# 418854  2017      2   28    19   11.0  32.0   3.0  24.0  400.0  72.0  12.5
# 418855  2017      2   28    20   13.0  32.0   3.0  41.0  500.0  50.0  11.6
# 418856  2017      2   28    21   14.0  28.0   4.0  38.0  500.0  54.0  10.8
# 418857  2017      2   28    22   12.0  23.0   4.0  30.0  400.0  59.0  10.5
# 418858  2017      2   28    23   13.0  19.0   4.0  38.0  600.0  49.0   8.6
#
# ...

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO',
#        'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station', 'O',
#        'SO2_mean', 'No'],
#       dtype='object')

# %%
grp = df.groupby(['station','year','month']).describe().head(50).transpose()

# %%
grp
# Out:
# station   Aotizhongxin                                                      \
# year              2013
# month               3            4            5            6            7
# day count   744.000000   720.000000   744.000000   720.000000   744.000000
#     mean     16.000000    15.500000    16.000000    15.500000    16.000000
#     std       8.950289     8.661458     8.950289     8.661458     8.950289
#     min       1.000000     1.000000     1.000000     1.000000     1.000000
#     25%       8.000000     8.000000     8.000000     8.000000     8.000000
# ...                ...          ...          ...          ...          ...
# No  min       1.000000   745.000000  1465.000000  2209.000000  2929.000000
#     25%     186.750000   924.750000  1650.750000  2388.750000  3114.750000
#     50%     372.500000  1104.500000  1836.500000  2568.500000  3300.500000
#     75%     558.250000  1284.250000  2022.250000  2748.250000  3486.250000
# ...

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(x='SO2',y='PM2.5',data=df,hue='station')
# Out:
# <AxesSubplot:xlabel='SO2', ylabel='PM2.5'>

# %%
df.corr()[['PM2.5','PM10']].sort_values(by='PM2.5').plot(kind='bar',figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# year          int64
# month         int64
# day           int64
# hour          int64
# PM2.5       float64
# PM10        float64
# SO2         float64
# NO2         float64
# CO          float64
# O3          float64
# TEMP        float64
# PRES        float64
# DEWP        float64
# RAIN        float64
# wd           object
# WSPM        float64
# station      object
# O           float64
# SO2_mean    float64
# No            int64
# dtype: object

# %%
df['station'].unique()
# Out:
# array(['Aotizhongxin', 'Changping', 'Dingling', 'Dongsi', 'Guanyuan',
#        'Gucheng', 'Huairou', 'Nongzhanguan', 'Shunyi', 'Tiantan',
#        'Wanliu', 'Wanshouxigong'], dtype=object)

# %%
df.groupby('station').describe()[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO',
       'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM', 'O',
       'SO2_mean', 'No']]
# Out:
#                  PM2.5                                                       \
#                  count       mean        std  min   25%   50%    75%    max
# station
# Aotizhongxin   34977.0  82.756179  81.055162  3.0  23.0  61.0  112.0  898.0
# Changping      34913.0  70.989806  71.481636  2.0  18.0  48.0   98.0  882.0
# Dingling       34913.0  65.883417  71.418126  3.0  14.0  42.0   91.0  881.0
# Dongsi         34980.0  86.157085  85.645802  3.0  23.0  63.0  117.0  737.0
# Guanyuan       34977.0  82.910793  80.228688  2.0  24.0  61.0  113.0  680.0
# Gucheng        34898.0  83.762731  82.041814  2.0  24.0  61.0  114.0  770.0
# Huairou        34754.0  69.486151  70.228840  2.0  18.0  48.0   96.0  762.0
# Nongzhanguan   34980.0  84.812938  85.462815  2.0  23.0  60.0  114.0  844.0
# Shunyi         34572.0  78.975317  79.641806  2.0  20.0  57.0  109.0  941.0
# Tiantan        34980.0  82.150699  80.165969  3.0  23.0  60.0  112.0  821.0
# ...

# %%
df
# Out:
#         year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# No
# 1       2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 2       2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 3       2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 4       2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 5       2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
# ...      ...    ...  ...   ...    ...   ...   ...   ...    ...   ...   ...
# 420764  2017      2   28    19   11.0  32.0   3.0  24.0  400.0  72.0  12.5
# 420765  2017      2   28    20   13.0  32.0   3.0  41.0  500.0  50.0  11.6
# 420766  2017      2   28    21   14.0  28.0   4.0  38.0  500.0  54.0  10.8
# 420767  2017      2   28    22   12.0  23.0   4.0  30.0  400.0  59.0  10.5
# 420768  2017      2   28    23   13.0  19.0   4.0  38.0  600.0  49.0   8.6
#
# ...

# %%
df[df['year']==2013]
# Out:
#         year  month  day  hour  PM2.5   PM10   SO2   NO2      CO    O3  TEMP  \
# No
# 1       2013      3    1     0    4.0    4.0   4.0   7.0   300.0  77.0  -0.7
# 2       2013      3    1     1    8.0    8.0   4.0   7.0   300.0  77.0  -1.1
# 3       2013      3    1     2    7.0    7.0   5.0  10.0   300.0  73.0  -1.1
# 4       2013      3    1     3    6.0    6.0  11.0  11.0   300.0  72.0  -1.4
# 5       2013      3    1     4    3.0    3.0  12.0  12.0   300.0  72.0  -2.0
# ...      ...    ...  ...   ...    ...    ...   ...   ...     ...   ...   ...
# 393044  2013     12   31    19   21.0   81.0   5.0  47.0   600.0  22.0   7.2
# 393045  2013     12   31    20   21.0   81.0   5.0  47.0   700.0   7.0   2.8
# 393046  2013     12   31    21   26.0  105.0   8.0  74.0   800.0   1.0   3.5
# 393047  2013     12   31    22   20.0   76.0   8.0  65.0   800.0   6.0   2.8
# 393048  2013     12   31    23   29.0  111.0  20.0  79.0  1100.0   1.0   1.3
#
# ...

# %%
df.groupby('year').describe()[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO',
       'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM', 'O',
       'SO2_mean', 'No']]
# Out:
#          PM2.5                                                        \
#          count       mean         std  min   25%   50%    75%    max
# year
# 2013   88094.0  79.979270   72.284976  2.0  24.0  60.0  112.0  844.0
# 2014  105105.0  85.401339   80.602832  3.0  24.0  65.0  118.0  809.0
# 2015  104523.0  79.540697   83.417574  3.0  21.0  54.0  107.0  762.0
# 2016  104631.0  71.911496   74.830679  3.0  18.0  50.0   97.0  999.0
# 2017   16505.0  92.183229  112.501198  2.0  12.0  47.0  130.0  835.0
#
#           PM10              ...   SO2_mean                   No  \
#          count        mean  ...        75%        max     count
# year                        ...
# 2013   88094.0  102.765943  ...  18.376481  18.689242   88094.0
# 2014  105105.0  115.847782  ...  18.376481  18.689242  105105.0
# 2015  104523.0  103.546331  ...  18.376481  18.689242  104523.0
# 2016  104631.0   94.591125  ...  18.376481  18.689242  104631.0
# ...

# %%
df.groupby('month').mean()[['PM2.5','PM10']].plot(kind='bar',figsize=(16,8));

# %%
df.groupby(['month','year']).mean()[['PM2.5','PM10']].plot(kind='bar',figsize=(16,8));

# %%
df.station.unique()
# Out:
# array(['Aotizhongxin', 'Changping', 'Dingling', 'Dongsi', 'Guanyuan',
#        'Gucheng', 'Huairou', 'Nongzhanguan', 'Shunyi', 'Tiantan',
#        'Wanliu', 'Wanshouxigong'], dtype=object)

# %%
df_sh = df[df['station']=='Shunyi']

# %%
34572*12
# Out:
# 414864

# %%
df['time'] = pd.to_datetime(df[['year','month','day','hour']])

# %%
df
# Out:
#         year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  ...  \
# No                                                                    ...
# 1       2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  ...
# 2       2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  ...
# 3       2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  ...
# 4       2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  ...
# 5       2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  ...
# ...      ...    ...  ...   ...    ...   ...   ...   ...    ...   ...  ...
# 420764  2017      2   28    19   11.0  32.0   3.0  24.0  400.0  72.0  ...
# 420765  2017      2   28    20   13.0  32.0   3.0  41.0  500.0  50.0  ...
# 420766  2017      2   28    21   14.0  28.0   4.0  38.0  500.0  54.0  ...
# 420767  2017      2   28    22   12.0  23.0   4.0  30.0  400.0  59.0  ...
# 420768  2017      2   28    23   13.0  19.0   4.0  38.0  600.0  49.0  ...
#
# ...

# %%
df.drop(['year','month','day','hour'],axis=1,inplace=True)

# %%
df.set_index('time')
# Out:
#                      PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  DEWP  \
# time
# 2013-03-01 00:00:00    4.0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0 -18.8
# 2013-03-01 01:00:00    8.0   8.0   4.0   7.0  300.0  77.0  -1.1  1023.2 -18.2
# 2013-03-01 02:00:00    7.0   7.0   5.0  10.0  300.0  73.0  -1.1  1023.5 -18.2
# 2013-03-01 03:00:00    6.0   6.0  11.0  11.0  300.0  72.0  -1.4  1024.5 -19.4
# 2013-03-01 04:00:00    3.0   3.0  12.0  12.0  300.0  72.0  -2.0  1025.2 -19.5
# ...                    ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2017-02-28 19:00:00   11.0  32.0   3.0  24.0  400.0  72.0  12.5  1013.5 -16.2
# 2017-02-28 20:00:00   13.0  32.0   3.0  41.0  500.0  50.0  11.6  1013.6 -15.1
# 2017-02-28 21:00:00   14.0  28.0   4.0  38.0  500.0  54.0  10.8  1014.2 -13.3
# 2017-02-28 22:00:00   12.0  23.0   4.0  30.0  400.0  59.0  10.5  1014.4 -12.9
# 2017-02-28 23:00:00   13.0  19.0   4.0  38.0  600.0  49.0   8.6  1014.1 -15.9
#
# ...

# %%
df.groupby([df['time'].dt.year,df['time'].dt.month,df['time'].dt.day,'station'])['PM2.5'].describe().head(60)
# Out:
#                               count        mean        std   min         25%  \
# time time time station
# 2013 3    1    Aotizhongxin    24.0    7.125000   5.041674   3.0    3.000000
#                Changping       24.0    5.083333   2.602953   3.0    3.000000
#                Dingling        24.0    6.375000   2.355613   3.0    5.000000
#                Dongsi          24.0    6.416667   4.432260   3.0    3.000000
#                Guanyuan        24.0    7.541667   4.221881   3.0    3.000000
#                Gucheng         24.0    8.625000   4.220164   3.0    5.000000
#                Huairou         24.0    7.541667   6.433467   3.0    3.000000
#                Nongzhanguan    24.0    6.458333   3.867132   3.0    3.000000
#                Shunyi          24.0    8.083333   3.740689   3.0    5.000000
#                Tiantan         24.0    8.625000   3.004526   3.0    6.000000
#                Wanliu          24.0    8.000000   4.263087   3.0    3.000000
# ...

# %%
df.time
# Out:
# No
# 1        2013-03-01 00:00:00
# 2        2013-03-01 01:00:00
# 3        2013-03-01 02:00:00
# 4        2013-03-01 03:00:00
# 5        2013-03-01 04:00:00
#                  ...
# 420764   2017-02-28 19:00:00
# 420765   2017-02-28 20:00:00
# 420766   2017-02-28 21:00:00
# 420767   2017-02-28 22:00:00
# 420768   2017-02-28 23:00:00
# Name: time, Length: 418858, dtype: datetime64[ns]
